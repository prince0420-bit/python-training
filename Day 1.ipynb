# %% [markdown]
# <a href="https://colab.research.google.com/github/prince0420-bit/python-training/blob/main/Day%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Basics (Day 1)

# %%
print("Prince\nRKGIT")
# Out:
# Prince
# RKGIT

# %%
a=input("enter the name")
print(a)
# Out:
# enter the nameprince
# prince

# %%
age=input("enter the age")
college_name=input("enter the college name")
print(f"{age}\n{college_name}")
# Out:
# enter the age21
# enter the college namerkgit
# 21
# rkgit

# %%
marks=int(input("enter the marks"))
total_marks=int(input("enter the total marks"))
percentage=(marks/total_marks)*100
print(percentage)
# Out:
# enter the marks450
# enter the total marks500
# 90.0

# %%
print("h"*4)
# Out:
# hhhh

# %%
p=float(input("enter the principle"))
r=float(input("enter the rate"))
t=float(input("enter the time"))
si=(p*r*t)/100
print(si)
# Out:
# enter the principle123
# enter the rate123
# enter the time2
# 302.58

# %%
cp=int(input("enter the cost price"))
bill=cp+(10/100*cp)
print(bill)
# Out:
# enter the cost price12
# 13.2

# %%
celcius=int(input("enter the celcius"))
farenheit=(celcius*9/5)+32
print(farenheit)
# Out:
# enter the celcius32
# 89.6

# %%
a=12
b=22
a,b=b,a
print(a,b)
# Out:
# 22 12

# %%
a=12
b=22
a=a+b
b=a-b
a=a-b
print(a,b)
# Out:
# 22 12
