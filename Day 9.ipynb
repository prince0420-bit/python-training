# %% [markdown]
# <a href="https://colab.research.google.com/github/prince0420-bit/python-training/blob/main/Day%209.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
names=["raju","ramesh","sanju"]

nums=[122,123,1234]

print(names)

names.append("ravi")
print(names)

names.extend("ravi")
print(names)

count=names.count("ravi")
print(count)

index=names.index("ravi")
print(index )

names.pop()
print(names)

names.pop(2)
print(names)

# names.clear()
# print(names)

print(names[:2])     ##slicing
# Out:
# ['raju', 'ramesh', 'sanju']
# ['raju', 'ramesh', 'sanju', 'ravi']
# ['raju', 'ramesh', 'sanju', 'ravi', 'r', 'a', 'v', 'i']
# 1
# 3
# ['raju', 'ramesh', 'sanju', 'ravi', 'r', 'a', 'v']
# ['raju', 'ramesh', 'ravi', 'r', 'a', 'v']
# ['raju', 'ramesh']

# %%
words=(1,"ramu","virat")

words_again=("hello","hey")

print(words)
print(words+words_again)
# Out:
# (1, 'ramu', 'virat')
# (1, 'ramu', 'virat', 'hello', 'hey')
