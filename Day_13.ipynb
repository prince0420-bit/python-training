# %% [markdown]
# <a href="https://colab.research.google.com/github/prince0420-bit/python-training/blob/main/Day_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  print(4/0)
except Exception as e:
  print(e)
# Out:
# division by zero

# %%
try:
    a=[1,4,2,0]
    print(a[5])
except Exception as e:
    print(e)
# Out:
# list index out of range

# %%
try:
    if True:
        print("hello")
except Exception as e:
    print(e)
# Out:
# hello

# %%
try:
  a=[2,"abc",true,45]
  print(a[6])
except Exception as error:
  print(error)
# Out:
# name 'true' is not defined
