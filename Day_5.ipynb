# %% [markdown]
# <a href="https://colab.research.google.com/github/prince0420-bit/python-training/blob/main/Day_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s="RKGIT"
reversed_string=s[::-1]
print(reversed_string)
# Out:
# TIGKR

# %%
s=("R","K","G","I","T")
r=len(s)-1
print(r)
# Out:
# 4

# %% [markdown]
# ## After that we solve the leet code problems
